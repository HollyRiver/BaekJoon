# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
sr = pd.read_csv("~/BaekJoon/statistic/lst.csv", index_col=0)
plt.hist(sr)
# Out:
# (array([509., 487., 489., 547., 505., 472., 456., 508., 520., 507.]),
#  array([6.0000e-04, 1.0048e-01, 2.0036e-01, 3.0024e-01, 4.0012e-01,
#         5.0000e-01, 5.9988e-01, 6.9976e-01, 7.9964e-01, 8.9952e-01,
#         9.9940e-01]),
#  <BarContainer object of 10 artists>)

# %%
sr2 = pd.read_csv("lst2.csv")
plt.hist(sr2)
# Out:
# (array([  10.,   72.,  279.,  738., 1228., 1233.,  909.,  399.,  111.,
#           21.]),
#  array([-0.5810999 , -0.37053789, -0.15997588,  0.05058614,  0.26114815,
#          0.47171016,  0.68227217,  0.89283419,  1.1033962 ,  1.31395821,
#          1.52452022]),
#  <BarContainer object of 10 artists>)

# %%
import random
import math

# %%
i = 0
lst = [[0]*5000]*100

for j in range(100) :
    while (i < 5000) :
        a = random.normalvariate(0.5, math.sqrt(0.1))
        if 0 <= a <= 1 :
            lst[j][i] = a
            i += 1

# %%
plt.hist(lst[5])
# Out:
# (array([275., 375., 513., 665., 705., 663., 604., 532., 406., 262.]),
#  array([9.58579282e-04, 1.00682362e-01, 2.00406145e-01, 3.00129928e-01,
#         3.99853711e-01, 4.99577493e-01, 5.99301276e-01, 6.99025059e-01,
#         7.98748842e-01, 8.98472625e-01, 9.98196408e-01]),
#  <BarContainer object of 10 artists>)

# %%
for i in lst2 :
    i.sort()
    if (i[1250] < 0.28) :
        print("A")
    else :
        print("B")
# Out:
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A

# %%
for i in lst :
    i.sort()
    if (i[1250] < 0.31) :
        print("A")
    else :
        print("B")
# Out:
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B
# B

# %%
lst2 = [[0]*5000]*100
for j in range(100) :
    for i in range(5000) :
        lst2[j][i] = random.random()
